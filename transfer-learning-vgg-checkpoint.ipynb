# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from __future__ import print_function
import keras
from keras.utils import to_categorical
import os
from keras.preprocessing.image import ImageDataGenerator, load_img
# Out:
# Using TensorFlow backend.

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/0e/2a/c3fe6035f0a8726e5b210680af3ccaf826f4a64ce7306e57017aba749447/tensorflow-1.10.0-cp36-cp36m-win_amd64.whl (37.7MB)
# Collecting grpcio>=1.8.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/0e/13/43a98e233716f1d9846ca65322b065443af5ea1aed5f631e240d231174c0/grpcio-1.15.0-cp36-cp36m-win_amd64.whl (1.5MB)
# Collecting absl-py>=0.1.6 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/16/db/cce5331638138c178dd1d5fb69f3f55eb3787a12efd9177177ae203e847f/absl-py-0.5.0.tar.gz (90kB)
# Collecting protobuf>=3.6.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/e8/df/d606d07cff0fc8d22abcc54006c0247002d11a7f2d218eb008d48e76851d/protobuf-3.6.1-cp36-cp36m-win_amd64.whl (1.1MB)
# Collecting tensorboard<1.11.0,>=1.10.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/c6/17/ecd918a004f297955c30b4fffbea100b1606c225dbf0443264012773c3ff/tensorboard-1.10.0-py3-none-any.whl (3.3MB)
# Requirement already satisfied: setuptools<=39.1.0 in c:\users\skelenja\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: numpy<=1.14.5,>=1.13.3 in c:\users\skelenja\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: six>=1.10.0 in c:\users\skelenja\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow)
# Collecting astor>=0.6.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/35/6b/11530768cac581a12952a2aad00e1526b89d242d0b9f59534ef6e6a1752f/astor-0.7.1-py2.py3-none-any.whl
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting gast>=0.2.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/5c/78/ff794fcae2ce8aa6323e789d1f8b3b7765f601e7702726f430e814822b96/gast-0.2.0.tar.gz
# Requirement already satisfied: wheel>=0.26 in c:\users\skelenja\appdata\local\continuum\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: werkzeug>=0.11.10 in c:\users\skelenja\appdata\local\continuum\anaconda3\lib\site-packages (from tensorboard<1.11.0,>=1.10.0->tensorflow)
# Collecting markdown>=2.6.8 (from tensorboard<1.11.0,>=1.10.0->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/6d/7d/488b90f470b96531a3f5788cf12a93332f543dbab13c423a5e7ce96a0493/Markdown-2.6.11-py2.py3-none-any.whl (78kB)
# Building wheels for collected packages: absl-py, termcolor, gast
#   Running setup.py bdist_wheel for absl-py: started
#   Running setup.py bdist_wheel for absl-py: finished with status 'done'
#   Stored in directory: C:\Users\skelenja\AppData\Local\pip\Cache\wheels\3c\33\ae\db8cd618e62f87594c13a5483f96e618044f9b01596efd013f
#   Running setup.py bdist_wheel for termcolor: started
#   Running setup.py bdist_wheel for termcolor: finished with status 'done'
#   Stored in directory: C:\Users\skelenja\AppData\Local\pip\Cache\wheels\7c\06\54\bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Running setup.py bdist_wheel for gast: started
#   Running setup.py bdist_wheel for gast: finished with status 'done'
#   Stored in directory: C:\Users\skelenja\AppData\Local\pip\Cache\wheels\9a\1f\0e\3cde98113222b853e98fc0a8e9924480a3e25f1b4008cedb4f
# Successfully built absl-py termcolor gast
# Installing collected packages: grpcio, absl-py, protobuf, markdown, tensorboard, astor, termcolor, gast, tensorflow
# Successfully installed absl-py-0.5.0 astor-0.7.1 gast-0.2.0 grpcio-1.15.0 markdown-2.6.11 protobuf-3.6.1 tensorboard-1.10.0 tensorflow-1.10.0 termcolor-1.1.0
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from keras.applications import VGG16

vgg_conv = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(224, 224, 3))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 131s 2us/step

# %%
vgg_conv.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dir = './clean-dataset/train'
validation_dir = './clean-dataset/validation'

nTrain = 600
nVal = 150

# %%
datagen = ImageDataGenerator(rescale=1./255)
batch_size = 20

train_features = np.zeros(shape=(nTrain, 7, 7, 512))
train_labels = np.zeros(shape=(nTrain,3))

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)

i = 0
for inputs_batch, labels_batch in train_generator:
    features_batch = vgg_conv.predict(inputs_batch)
    train_features[i * batch_size : (i + 1) * batch_size] = features_batch
    train_labels[i * batch_size : (i + 1) * batch_size] = labels_batch
    i += 1
    if i * batch_size >= nTrain:
        break
        
train_features = np.reshape(train_features, (nTrain, 7 * 7 * 512))
# Out:
# Found 600 images belonging to 3 classes.

# %%
validation_features = np.zeros(shape=(nVal, 7, 7, 512))
validation_labels = np.zeros(shape=(nVal,3))

validation_generator = datagen.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)

i = 0
for inputs_batch, labels_batch in validation_generator:
    features_batch = vgg_conv.predict(inputs_batch)
    validation_features[i * batch_size : (i + 1) * batch_size] = features_batch
    validation_labels[i * batch_size : (i + 1) * batch_size] = labels_batch
    i += 1
    if i * batch_size >= nVal:
        break

validation_features = np.reshape(validation_features, (nVal, 7 * 7 * 512))
# Out:
# Found 150 images belonging to 3 classes.

# %% [markdown]
# ### Create your own model and train the network

# %%
from keras import models
from keras import layers
from keras import optimizers

model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_dim=7 * 7 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(3, activation='softmax'))

model.compile(optimizer=optimizers.RMSprop(lr=2e-4),
              loss='categorical_crossentropy',
              metrics=['acc'])

history = model.fit(train_features,
                    train_labels,
                    epochs=20,
                    batch_size=batch_size,
                    validation_data=(validation_features,validation_labels))
# Out:
# Train on 600 samples, validate on 150 samples
# Epoch 1/20
# 600/600 [==============================] - 6s 9ms/step - loss: 2.2864 - acc: 0.5800 - val_loss: 0.6551 - val_acc: 0.7200
# Epoch 2/20
# 600/600 [==============================] - 5s 8ms/step - loss: 0.5631 - acc: 0.8000 - val_loss: 0.6865 - val_acc: 0.7667
# Epoch 3/20
# 600/600 [==============================] - 5s 8ms/step - loss: 0.3106 - acc: 0.8767 - val_loss: 0.3292 - val_acc: 0.9000
# Epoch 4/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.1892 - acc: 0.9350 - val_loss: 0.6762 - val_acc: 0.7800
# Epoch 5/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.1544 - acc: 0.9450 - val_loss: 0.5415 - val_acc: 0.8600
# Epoch 6/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.1580 - acc: 0.9467 - val_loss: 0.3576 - val_acc: 0.9000
# Epoch 7/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0422 - acc: 0.9867 - val_loss: 0.3742 - val_acc: 0.9000
# Epoch 8/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0361 - acc: 0.9867 - val_loss: 0.4812 - val_acc: 0.9000
# Epoch 9/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.1431 - acc: 0.9583 - val_loss: 0.5381 - val_acc: 0.8533
# Epoch 10/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0407 - acc: 0.9867 - val_loss: 1.0542 - val_acc: 0.7800
# Epoch 11/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0228 - acc: 0.9917 - val_loss: 0.3948 - val_acc: 0.9000
# Epoch 12/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0439 - acc: 0.9867 - val_loss: 0.9361 - val_acc: 0.8333
# Epoch 13/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0068 - acc: 0.9983 - val_loss: 0.4460 - val_acc: 0.8800
# Epoch 14/20
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0083 - acc: 0.9967 - val_loss: 0.3620 - val_acc: 0.9200
# Epoch 15/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0622 - acc: 0.9817 - val_loss: 0.4276 - val_acc: 0.9067
# Epoch 16/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0032 - acc: 0.9983 - val_loss: 0.5481 - val_acc: 0.8733
# Epoch 17/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 0.4981 - val_acc: 0.8933
# Epoch 18/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0586 - acc: 0.9800 - val_loss: 0.5074 - val_acc: 0.9067
# Epoch 19/20
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0035 - acc: 0.9983 - val_loss: 0.5279 - val_acc: 0.8733
# Epoch 20/20
# 600/600 [==============================] - 5s 9ms/step - loss: 8.6890e-04 - acc: 1.0000 - val_loss: 0.4651 - val_acc: 0.8933

# %%
fnames = validation_generator.filenames

ground_truth = validation_generator.classes

label2index = validation_generator.class_indices

# Getting the mapping from class index to class label
idx2label = dict((v,k) for k,v in label2index.items())

# %%
predictions = model.predict_classes(validation_features)
prob = model.predict(validation_features)

# %%
errors = np.where(predictions != ground_truth)[0]
print("No of errors = {}/{}".format(len(errors),nVal))
# Out:
# No of errors = 16/150

# %% [markdown]
# ### Let us see which images were predicted wrongly

# %%
for i in range(len(errors)):
    pred_class = np.argmax(prob[errors[i]])
    pred_label = idx2label[pred_class]
    
    print('Original label:{}, Prediction :{}, confidence : {:.3f}'.format(
        fnames[errors[i]].split('/')[0],
        pred_label,
        prob[errors[i]][pred_class]))
    
    original = load_img('{}/{}'.format(validation_dir,fnames[errors[i]]))
    plt.imshow(original)
    plt.show()
# Out:
# Original label:pumpkin\01bd57bf37f37a7a40f45f44285058a4056a7d25.jpg, Prediction :tomato, confidence : 0.390
# Original label:pumpkin\02dbfd2030c170f723905d272d62f236058234b8.jpg, Prediction :tomato, confidence : 1.000
# Original label:pumpkin\1ec93d0b4866977218e284c997b73bbed4e2f3df.jpg, Prediction :tomato, confidence : 0.794
# Original label:pumpkin\2aa81cc7faeda20bf669ca0dcd47b18ad581a457.jpg, Prediction :watermelon, confidence : 0.754
# Original label:pumpkin\2b6bc4405ab63bb6606363e14a474bd90f3ae251.jpg, Prediction :tomato, confidence : 0.990
# Original label:pumpkin\2f95895ea809b540e494fd662483558e8cb344ff.jpg, Prediction :watermelon, confidence : 0.925
# Original label:pumpkin\3ef4265a811c4745cffc7299779d465fa5663627.jpg, Prediction :watermelon, confidence : 1.000
# Original label:pumpkin\3f5a99505095bd427f943dd0b7cfea2b3f265ec6.jpg, Prediction :tomato, confidence : 0.736
# Original label:pumpkin\7bb95510e57bef5b5009646f078101e2b88d1153.jpg, Prediction :tomato, confidence : 0.998
# Original label:tomato\0b8c5c525edeaeaa2688e0189b906e50048a1179.jpg, Prediction :pumpkin, confidence : 0.995
# Original label:tomato\0c05a12a9142b662fda867808d9242b91bcc7d72.jpg, Prediction :pumpkin, confidence : 0.980
# Original label:tomato\1a7c701284d83f67efb0f2057ddfe0a875ce27c4.jpg, Prediction :watermelon, confidence : 1.000
# Original label:tomato\1ec795e5e7f0cddad202d49ef53fe4d135159867.jpg, Prediction :pumpkin, confidence : 0.726
# Original label:watermelon\4f341bbb54adf1db82fb435b51d87eae5387fe8f.jpg, Prediction :pumpkin, confidence : 0.580
# Original label:watermelon\5a46b693ba0ee8161c9f4a25915eb0374dc5b8d3.jpg, Prediction :tomato, confidence : 0.596
# Original label:watermelon\5a9580fc46939841ecd11fccb26d1883329d0ef0.jpg, Prediction :pumpkin, confidence : 0.737
